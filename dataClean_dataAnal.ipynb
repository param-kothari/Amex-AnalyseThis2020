# %%
import pandas as pd 
data = pd.read_csv("Training_Data_0611N.csv") #data imported

# %%
data.head()#Head of data displayed here for reference
# Out:
#     cust_id  profitable_flag  count_accts  cm_age  flag_top_ed_spender  \
# 0  550391.0              0.0          1.0    74.0                  1.0
# 1  550392.0              0.0          1.0    64.0                  0.0
# 2  550393.0              0.0          1.0    75.0                  1.0
# 3  550394.0              0.0          2.0    73.0                  0.0
# 4  550395.0              0.0          2.0    68.0                  0.0
#
#    flag_cust_fee_paid_6m pre6m_cust_spend  pre6m_cust_roc_cnt  \
# 0                    0.0           1,518                122.0
# 1                    0.0           4,807                354.0
# 2                    0.0           2,361                204.0
# 3                    1.0           5,452                142.0
# 4                    0.0             170                 34.0
#
#   pre6m_cust_non_disc_amt  pre6m_cust_non_disc_cnt  ...  \
# 0                    811                      96.0  ...
# 1                  1,052                      82.0  ...
# 2                  1,351                     118.0  ...
# 3                  1,195                      50.0  ...
# 4                     88                      20.0  ...
#
#   cnsumr_chrg_actv_cust_cnt  cnsumr_chrg_avg_credit_12m_amt  \
# 0                       0.0                            -
# 1                       0.0                              7
# 2                       0.0                            -
# 3                       1.0                            493
# 4                       0.0                            -
#
#   cnsumr_lend_actv_cust_cnt cnsumr_lend_tot_util_ratio  \
# 0                       1.0                   0.034044
# 1                       1.0                   0.044086
# 2                       1.0                   0.039613
# 3                       1.0                   0.001200
# 4                       2.0                   0.003378
#
#    sow_revol_avg_paydown_pct sow_tot_annual_ext_pmt_amt  \
# 0                     0.0000                       991
# 1                     0.0877                         2
# 2                     0.0000                     4,828
# 3                     0.0000                     4,598
# 4                     0.0168                     2,176
#
#    sow_tot_revol_bal_amt sow_tot_revol_cnt  sow_tot_trans_bal_amt  \
# 0                   -                  0.0                   -
# 1                    24                2.0                   -
# 2                   -                  0.0                   387
# 3                   -                  0.0                   295
# 4                 2,606                5.0                   143
#
#    sow_tot_trans_cnt
# 0                3.0
# 1                0.0
# 2                3.0
# 3                4.0
# 4               13.0
#
# [5 rows x 50 columns]

# %%
data.info() # Basic info of data that can be compared after data cleaning
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19599 entries, 0 to 19598
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cust_id                         19595 non-null  float64
#  1   profitable_flag                 19595 non-null  float64
#  2   count_accts                     19595 non-null  float64
#  3   cm_age                          19595 non-null  float64
#  4   flag_top_ed_spender             19547 non-null  float64
#  5   flag_cust_fee_paid_6m           19595 non-null  float64
#  6   pre6m_cust_spend                19595 non-null  object
#  7   pre6m_cust_roc_cnt              19595 non-null  float64
#  8   pre6m_cust_non_disc_amt         19595 non-null  object
#  9   pre6m_cust_non_disc_cnt         19595 non-null  float64
#  10  pre6m_cust_disc_amt             19595 non-null  object
#  11  pre6m_cust_disc_cnt             19595 non-null  float64
#  12  pre6m_cust_outbound_amt         19595 non-null  object
#  13  pre6m_cust_online_amt           19595 non-null  object
#  14  pre6m_cust_online_cnt           19595 non-null  float64
#  15  pre6m_cust_travel_amt           19595 non-null  object
#  16  pre6m_cust_travel_cnt           19595 non-null  float64
#  17  pre6m_cust_retail_amt           19595 non-null  object
#  18  pre6m_cust_retail_cnt           19595 non-null  float64
#  19  pre6m_cust_myca_active          19595 non-null  float64
#  20  pre6m_cust_mob_logins           19595 non-null  float64
#  21  pre6m_total_mc_trs              19595 non-null  object
#  22  acq_sub_chn                     18693 non-null  object
#  23  acq_type_grp                    18723 non-null  object
#  24  fee_type_grp                    19595 non-null  object
#  25  Cust_tenure                     19359 non-null  float64
#  26  pre6m_spend_active_ind          19359 non-null  float64
#  27  highly_utilized_ind             19359 non-null  float64
#  28  min_pay_ind                     19359 non-null  float64
#  29  paid_in_full_ind                19359 non-null  float64
#  30  sum_total_line_amt              19595 non-null  object
#  31  direct_debit_ind                19359 non-null  float64
#  32  referrals                       19359 non-null  float64
#  33  spillover                       19359 non-null  float64
#  34  self_accts                      19359 non-null  float64
#  35  Customer Low Quality indicator  19359 non-null  float64
#  36  cdss_most_rcnt_prob             19350 non-null  float64
#  37  cust_max_credit_12m_amt         19595 non-null  object
#  38  cust_max_remit_12m_amt          19595 non-null  object
#  39  cbr_3_score                     19350 non-null  float64
#  40  cnsumr_chrg_actv_cust_cnt       19350 non-null  float64
#  41  cnsumr_chrg_avg_credit_12m_amt  19595 non-null  object
#  42  cnsumr_lend_actv_cust_cnt       19350 non-null  float64
#  43  cnsumr_lend_tot_util_ratio      19350 non-null  float64
#  44  sow_revol_avg_paydown_pct       19350 non-null  float64
#  45  sow_tot_annual_ext_pmt_amt      19595 non-null  object
#  46  sow_tot_revol_bal_amt           19595 non-null  object
#  47  sow_tot_revol_cnt               19350 non-null  float64
#  48  sow_tot_trans_bal_amt           19595 non-null  object
#  49  sow_tot_trans_cnt               19350 non-null  float64
# dtypes: float64(32), object(18)
# memory usage: 7.5+ MB

# %%
data.describe()
# Out:
#              cust_id  profitable_flag   count_accts        cm_age  \
# count   19595.000000     19595.000000  19595.000000  19595.000000
# mean   560188.000000         0.185966      1.227558     42.700128
# std      5656.733598         0.389089      0.515668     11.588827
# min    550391.000000         0.000000      1.000000     24.000000
# 25%    555289.500000         0.000000      1.000000     34.000000
# 50%    560188.000000         0.000000      1.000000     39.000000
# 75%    565086.500000         0.000000      1.000000     48.000000
# max    569985.000000         1.000000      6.000000     99.000000
#
#        flag_top_ed_spender  flag_cust_fee_paid_6m  pre6m_cust_roc_cnt  \
# count         19547.000000           19595.000000        19595.000000
# mean              0.530874               0.242103          448.679765
# std               0.499059               0.428367          531.939134
# min               0.000000               0.000000            0.000000
# 25%               0.000000               0.000000          126.000000
# 50%               1.000000               0.000000          348.000000
# 75%               1.000000               0.000000          666.000000
# max               1.000000               1.000000        49264.000000
#
#        pre6m_cust_non_disc_cnt  pre6m_cust_disc_cnt  pre6m_cust_online_cnt  \
# count             19595.000000         19595.000000           19595.000000
# mean                142.604134           306.075632             247.239398
# std                 136.466289           465.602922             762.833133
# min                   0.000000             0.000000               0.000000
# 25%                  34.000000            72.000000              48.000000
# 50%                 108.000000           210.000000             156.000000
# 75%                 214.000000           444.000000             336.000000
# max                1260.000000         49264.000000           98504.000000
#
#        ...    self_accts  Customer Low Quality indicator  cdss_most_rcnt_prob  \
# count  ...  19359.000000                    19359.000000         19350.000000
# mean   ...      0.029185                        0.008781             0.007338
# std    ...      0.270508                        0.093299             0.042707
# min    ...      0.000000                        0.000000             0.000000
# 25%    ...      0.000000                        0.000000             0.000000
# 50%    ...      0.000000                        0.000000             0.000000
# 75%    ...      0.000000                        0.000000             0.001000
# max    ...     11.000000                        1.000000             0.997000
#
#         cbr_3_score  cnsumr_chrg_actv_cust_cnt  cnsumr_lend_actv_cust_cnt  \
# count  19350.000000               19350.000000               19350.000000
# mean    1185.215659                   0.158966                   1.057416
# std      240.646855                   0.373485                   0.514165
# min        0.000000                   0.000000                   0.000000
# 25%     1118.000000                   0.000000                   1.000000
# 50%     1262.000000                   0.000000                   1.000000
# 75%     1331.000000                   0.000000                   1.000000
# max     1422.000000                   2.000000                   5.000000
#
#        cnsumr_lend_tot_util_ratio  sow_revol_avg_paydown_pct  \
# count                19350.000000               19350.000000
# mean                     0.133133                   0.016669
# std                      0.217536                   0.059165
# min                     -5.540188                   0.000000
# 25%                      0.003551                   0.000000
# 50%                      0.054909                   0.000000
# 75%                      0.157450                   0.000000
# max                      4.718893                   0.498500
#
#        sow_tot_revol_cnt  sow_tot_trans_cnt
# count       19350.000000       19350.000000
# mean            0.433902           0.787339
# std             1.082492           1.187996
# min             0.000000           0.000000
# 25%             0.000000           0.000000
# 50%             0.000000           0.000000
# 75%             0.000000           2.000000
# max            10.000000          13.000000
#
# [8 rows x 32 columns]

# %%
dataTypeDict = dict(data.dtypes) #Dictionary containing column names as keys and data-types as values

# %%
colObj_list = []#List containing "object" data-type column names
for var in dataTypeDict:
    if dataTypeDict[var] == 'object':
        data[var] = data[var].str.replace(',', '')
        data[var] = data[var].str.replace(' ', '')
        data[var] = data[var].str.replace('-', '0')
        data[var] = data[var].str.replace('(', '-')
        data[var] = data[var].str.replace(')', '')
        colObj_list.append(var)
        if (var != 'acq_sub_chn' and var!= 'acq_type_grp' and var!= 'fee_type_grp'):
            dataTypeDict[var] = 'float'

# %%
data = data.astype(dataTypeDict) #Converting all numerical objects (numbers in the form of strings) 
                                #except 3 columns which contained alphabet-strings
#NOTE: DO NOT USE dataTypeDict anymore.

# %%
data.isnull().sum(axis=0) #Sum of NaN values in each column of the main dataframe
# Out:
# cust_id                             4
# profitable_flag                     4
# count_accts                         4
# cm_age                              4
# flag_top_ed_spender                52
# flag_cust_fee_paid_6m               4
# pre6m_cust_spend                    4
# pre6m_cust_roc_cnt                  4
# pre6m_cust_non_disc_amt             4
# pre6m_cust_non_disc_cnt             4
# pre6m_cust_disc_amt                 4
# pre6m_cust_disc_cnt                 4
# pre6m_cust_outbound_amt             4
# pre6m_cust_online_amt               4
# pre6m_cust_online_cnt               4
# pre6m_cust_travel_amt               4
# pre6m_cust_travel_cnt               4
# pre6m_cust_retail_amt               4
# pre6m_cust_retail_cnt               4
# pre6m_cust_myca_active              4
# pre6m_cust_mob_logins               4
# pre6m_total_mc_trs                  4
# acq_sub_chn                       906
# acq_type_grp                      876
# fee_type_grp                        4
# Cust_tenure                       240
# pre6m_spend_active_ind            240
# highly_utilized_ind               240
# min_pay_ind                       240
# paid_in_full_ind                  240
# sum_total_line_amt                  4
# direct_debit_ind                  240
# referrals                         240
# spillover                         240
# self_accts                        240
# Customer Low Quality indicator    240
# cdss_most_rcnt_prob               249
# cust_max_credit_12m_amt             4
# cust_max_remit_12m_amt              4
# cbr_3_score                       249
# cnsumr_chrg_actv_cust_cnt         249
# cnsumr_chrg_avg_credit_12m_amt      4
# cnsumr_lend_actv_cust_cnt         249
# cnsumr_lend_tot_util_ratio        249
# sow_revol_avg_paydown_pct         249
# sow_tot_annual_ext_pmt_amt          4
# sow_tot_revol_bal_amt               4
# sow_tot_revol_cnt                 249
# sow_tot_trans_bal_amt               4
# sow_tot_trans_cnt                 249
# dtype: int64

# %%
data = data.dropna() #Dataset after dropping all rows with atleast 1 NaN value
data.isnull().sum(axis=0) #Checking how many NaN values
# Out:
# cust_id                           0
# profitable_flag                   0
# count_accts                       0
# cm_age                            0
# flag_top_ed_spender               0
# flag_cust_fee_paid_6m             0
# pre6m_cust_spend                  0
# pre6m_cust_roc_cnt                0
# pre6m_cust_non_disc_amt           0
# pre6m_cust_non_disc_cnt           0
# pre6m_cust_disc_amt               0
# pre6m_cust_disc_cnt               0
# pre6m_cust_outbound_amt           0
# pre6m_cust_online_amt             0
# pre6m_cust_online_cnt             0
# pre6m_cust_travel_amt             0
# pre6m_cust_travel_cnt             0
# pre6m_cust_retail_amt             0
# pre6m_cust_retail_cnt             0
# pre6m_cust_myca_active            0
# pre6m_cust_mob_logins             0
# pre6m_total_mc_trs                0
# acq_sub_chn                       0
# acq_type_grp                      0
# fee_type_grp                      0
# Cust_tenure                       0
# pre6m_spend_active_ind            0
# highly_utilized_ind               0
# min_pay_ind                       0
# paid_in_full_ind                  0
# sum_total_line_amt                0
# direct_debit_ind                  0
# referrals                         0
# spillover                         0
# self_accts                        0
# Customer Low Quality indicator    0
# cdss_most_rcnt_prob               0
# cust_max_credit_12m_amt           0
# cust_max_remit_12m_amt            0
# cbr_3_score                       0
# cnsumr_chrg_actv_cust_cnt         0
# cnsumr_chrg_avg_credit_12m_amt    0
# cnsumr_lend_actv_cust_cnt         0
# cnsumr_lend_tot_util_ratio        0
# sow_revol_avg_paydown_pct         0
# sow_tot_annual_ext_pmt_amt        0
# sow_tot_revol_bal_amt             0
# sow_tot_revol_cnt                 0
# sow_tot_trans_bal_amt             0
# sow_tot_trans_cnt                 0
# dtype: int64

# %%
data.info() # Checking info about dataset post removing rows with NaN values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18357 entries, 0 to 19594
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cust_id                         18357 non-null  float64
#  1   profitable_flag                 18357 non-null  float64
#  2   count_accts                     18357 non-null  float64
#  3   cm_age                          18357 non-null  float64
#  4   flag_top_ed_spender             18357 non-null  float64
#  5   flag_cust_fee_paid_6m           18357 non-null  float64
#  6   pre6m_cust_spend                18357 non-null  float64
#  7   pre6m_cust_roc_cnt              18357 non-null  float64
#  8   pre6m_cust_non_disc_amt         18357 non-null  float64
#  9   pre6m_cust_non_disc_cnt         18357 non-null  float64
#  10  pre6m_cust_disc_amt             18357 non-null  float64
#  11  pre6m_cust_disc_cnt             18357 non-null  float64
#  12  pre6m_cust_outbound_amt         18357 non-null  float64
#  13  pre6m_cust_online_amt           18357 non-null  float64
#  14  pre6m_cust_online_cnt           18357 non-null  float64
#  15  pre6m_cust_travel_amt           18357 non-null  float64
#  16  pre6m_cust_travel_cnt           18357 non-null  float64
#  17  pre6m_cust_retail_amt           18357 non-null  float64
#  18  pre6m_cust_retail_cnt           18357 non-null  float64
#  19  pre6m_cust_myca_active          18357 non-null  float64
#  20  pre6m_cust_mob_logins           18357 non-null  float64
#  21  pre6m_total_mc_trs              18357 non-null  float64
#  22  acq_sub_chn                     18357 non-null  object
#  23  acq_type_grp                    18357 non-null  object
#  24  fee_type_grp                    18357 non-null  object
#  25  Cust_tenure                     18357 non-null  float64
#  26  pre6m_spend_active_ind          18357 non-null  float64
#  27  highly_utilized_ind             18357 non-null  float64
#  28  min_pay_ind                     18357 non-null  float64
#  29  paid_in_full_ind                18357 non-null  float64
#  30  sum_total_line_amt              18357 non-null  float64
#  31  direct_debit_ind                18357 non-null  float64
#  32  referrals                       18357 non-null  float64
#  33  spillover                       18357 non-null  float64
#  34  self_accts                      18357 non-null  float64
#  35  Customer Low Quality indicator  18357 non-null  float64
#  36  cdss_most_rcnt_prob             18357 non-null  float64
#  37  cust_max_credit_12m_amt         18357 non-null  float64
#  38  cust_max_remit_12m_amt          18357 non-null  float64
#  39  cbr_3_score                     18357 non-null  float64
#  40  cnsumr_chrg_actv_cust_cnt       18357 non-null  float64
#  41  cnsumr_chrg_avg_credit_12m_amt  18357 non-null  float64
#  42  cnsumr_lend_actv_cust_cnt       18357 non-null  float64
#  43  cnsumr_lend_tot_util_ratio      18357 non-null  float64
#  44  sow_revol_avg_paydown_pct       18357 non-null  float64
#  45  sow_tot_annual_ext_pmt_amt      18357 non-null  float64
#  46  sow_tot_revol_bal_amt           18357 non-null  float64
#  47  sow_tot_revol_cnt               18357 non-null  float64
#  48  sow_tot_trans_bal_amt           18357 non-null  float64
#  49  sow_tot_trans_cnt               18357 non-null  float64
# dtypes: float64(47), object(3)
# memory usage: 7.1+ MB

# %%
data.describe()
# Out:
#              cust_id  profitable_flag   count_accts        cm_age  \
# count   18357.000000     18357.000000  18357.000000  18357.000000
# mean   560330.030669         0.186741      1.229068     42.134989
# std      5583.955817         0.389714      0.519072     11.175163
# min    550391.000000         0.000000      1.000000     24.000000
# 25%    555504.000000         0.000000      1.000000     34.000000
# 50%    560337.000000         0.000000      1.000000     39.000000
# 75%    565166.000000         0.000000      1.000000     47.000000
# max    569985.000000         1.000000      6.000000     97.000000
#
#        flag_top_ed_spender  flag_cust_fee_paid_6m  pre6m_cust_spend  \
# count         18357.000000           18357.000000      18357.000000
# mean              0.531241               0.240235       5071.535545
# std               0.499037               0.427238       7747.572346
# min               0.000000               0.000000     -14975.000000
# 25%               0.000000               0.000000       1479.000000
# 50%               1.000000               0.000000       3452.000000
# 75%               1.000000               0.000000       6384.000000
# max               1.000000               1.000000     308258.000000
#
#        pre6m_cust_roc_cnt  pre6m_cust_non_disc_amt  pre6m_cust_non_disc_cnt  \
# count        18357.000000             18357.000000             18357.000000
# mean           452.764068              1155.372773               143.362641
# std            539.081017              1862.440840               135.711346
# min              0.000000              -588.000000                 0.000000
# 25%            132.000000               241.000000                36.000000
# 50%            352.000000               688.000000               108.000000
# 75%            670.000000              1460.000000               212.000000
# max          49264.000000             55953.000000              1260.000000
#
#        ...  cnsumr_chrg_actv_cust_cnt  cnsumr_chrg_avg_credit_12m_amt  \
# count  ...               18357.000000                    18357.000000
# mean   ...                   0.152040                      128.400556
# std    ...                   0.366726                      523.834161
# min    ...                   0.000000                        0.000000
# 25%    ...                   0.000000                        0.000000
# 50%    ...                   0.000000                        0.000000
# 75%    ...                   0.000000                        0.000000
# max    ...                   2.000000                    23573.000000
#
#        cnsumr_lend_actv_cust_cnt  cnsumr_lend_tot_util_ratio  \
# count               18357.000000                18357.000000
# mean                    1.063736                    0.134125
# std                     0.511335                    0.218655
# min                     0.000000                   -5.540188
# 25%                     1.000000                    0.004007
# 50%                     1.000000                    0.055524
# 75%                     1.000000                    0.158306
# max                     5.000000                    4.718893
#
#        sow_revol_avg_paydown_pct  sow_tot_annual_ext_pmt_amt  \
# count               18357.000000                18357.000000
# mean                    0.016468                 2154.375225
# std                     0.058854                 6057.642242
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    0.000000
# 75%                     0.000000                 2091.000000
# max                     0.498500               170965.000000
#
#        sow_tot_revol_bal_amt  sow_tot_revol_cnt  sow_tot_trans_bal_amt  \
# count           18357.000000       18357.000000           18357.000000
# mean              450.200033           0.424198             113.632347
# std              1661.649191           1.065765             438.983844
# min              -546.000000           0.000000           -3000.000000
# 25%                 0.000000           0.000000               0.000000
# 50%                 0.000000           0.000000               0.000000
# 75%                 0.000000           0.000000              13.000000
# max             34113.000000          10.000000           16706.000000
#
#        sow_tot_trans_cnt
# count       18357.000000
# mean            0.768590
# std             1.179263
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             2.000000
# max            13.000000
#
# [8 rows x 47 columns]

# %%
data.head(20)
# Out:
#      cust_id  profitable_flag  count_accts  cm_age  flag_top_ed_spender  \
# 0   550391.0              0.0          1.0    74.0                  1.0
# 1   550392.0              0.0          1.0    64.0                  0.0
# 4   550395.0              0.0          2.0    68.0                  0.0
# 6   550397.0              0.0          2.0    69.0                  1.0
# 7   550398.0              1.0          2.0    58.0                  0.0
# 11  550402.0              0.0          4.0    66.0                  0.0
# 12  550403.0              0.0          1.0    56.0                  0.0
# 14  550405.0              1.0          1.0    60.0                  1.0
# 18  550409.0              0.0          1.0    74.0                  1.0
# 24  550415.0              0.0          1.0    64.0                  0.0
# 27  550418.0              0.0          1.0    69.0                  0.0
# 29  550420.0              0.0          2.0    74.0                  1.0
# 30  550421.0              1.0          3.0    86.0                  1.0
# 31  550422.0              0.0          1.0    77.0                  1.0
# 32  550423.0              0.0          2.0    78.0                  0.0
# 35  550426.0              0.0          1.0    65.0                  0.0
# 40  550431.0              1.0          1.0    78.0                  0.0
# 44  550435.0              0.0          1.0    58.0                  0.0
# 45  550436.0              0.0          1.0    72.0                  1.0
# 47  550438.0              0.0          3.0    70.0                  0.0
#
#     flag_cust_fee_paid_6m  pre6m_cust_spend  pre6m_cust_roc_cnt  \
# 0                     0.0            1518.0               122.0
# 1                     0.0            4807.0               354.0
# 4                     0.0             170.0                34.0
# 6                     1.0           12431.0               442.0
# 7                     0.0           22606.0               472.0
# 11                    1.0            1805.0                68.0
# 12                    0.0           11784.0               616.0
# 14                    0.0            8458.0               444.0
# 18                    1.0            7680.0               544.0
# 24                    1.0            1817.0               478.0
# 27                    1.0            9250.0               118.0
# 29                    1.0           13438.0               590.0
# 30                    0.0           11988.0              1296.0
# 31                    1.0            4306.0               684.0
# 32                    1.0            6456.0               170.0
# 35                    0.0           10520.0                50.0
# 40                    0.0            7642.0               176.0
# 44                    0.0             836.0               120.0
# 45                    0.0              96.0                 4.0
# 47                    0.0            3250.0               110.0
#
#     pre6m_cust_non_disc_amt  pre6m_cust_non_disc_cnt  ...  \
# 0                     811.0                     96.0  ...
# 1                    1052.0                     82.0  ...
# 4                      88.0                     20.0  ...
# 6                    5679.0                    232.0  ...
# 7                   10796.0                    182.0  ...
# 11                    233.0                     28.0  ...
# 12                   3765.0                    346.0  ...
# 14                    682.0                     30.0  ...
# 18                   2249.0                    346.0  ...
# 24                    553.0                     98.0  ...
# 27                   2112.0                     34.0  ...
# 29                   2839.0                    242.0  ...
# 30                   4431.0                    220.0  ...
# 31                   1839.0                    504.0  ...
# 32                   1187.0                     46.0  ...
# 35                   4371.0                     26.0  ...
# 40                    612.0                     34.0  ...
# 44                    516.0                     54.0  ...
# 45                      0.0                      0.0  ...
# 47                    201.0                     16.0  ...
#
#     cnsumr_chrg_actv_cust_cnt  cnsumr_chrg_avg_credit_12m_amt  \
# 0                         0.0                             0.0
# 1                         0.0                             7.0
# 4                         0.0                             0.0
# 6                         1.0                            19.0
# 7                         0.0                             0.0
# 11                        1.0                            50.0
# 12                        0.0                             0.0
# 14                        1.0                          1716.0
# 18                        0.0                             0.0
# 24                        1.0                           201.0
# 27                        0.0                             0.0
# 29                        1.0                           117.0
# 30                        1.0                           883.0
# 31                        0.0                             0.0
# 32                        1.0                           565.0
# 35                        0.0                             0.0
# 40                        0.0                            24.0
# 44                        1.0                           137.0
# 45                        0.0                             0.0
# 47                        1.0                           404.0
#
#     cnsumr_lend_actv_cust_cnt  cnsumr_lend_tot_util_ratio  \
# 0                         1.0                    0.034044
# 1                         1.0                    0.044086
# 4                         2.0                    0.003378
# 6                         1.0                    0.064085
# 7                         2.0                    0.143371
# 11                        3.0                   -0.000001
# 12                        1.0                    0.794952
# 14                        0.0                    0.000000
# 18                        1.0                    0.026119
# 24                        0.0                    0.000000
# 27                        1.0                    0.057182
# 29                        1.0                    0.129290
# 30                        2.0                    0.973091
# 31                        1.0                    0.030574
# 32                        1.0                    0.018102
# 35                        1.0                    0.820879
# 40                        1.0                    0.544081
# 44                        0.0                    0.000000
# 45                        1.0                    0.000000
# 47                        2.0                    0.000000
#
#     sow_revol_avg_paydown_pct  sow_tot_annual_ext_pmt_amt  \
# 0                      0.0000                       991.0
# 1                      0.0877                         2.0
# 4                      0.0168                      2176.0
# 6                      0.3565                      2967.0
# 7                      0.0000                     73575.0
# 11                     0.0000                       344.0
# 12                     0.0100                     13977.0
# 14                     0.0000                     33674.0
# 18                     0.0000                         0.0
# 24                     0.0000                         0.0
# 27                     0.1536                      2750.0
# 29                     0.0000                     10904.0
# 30                     0.0000                         0.0
# 31                     0.0000                         0.0
# 32                     0.0000                         0.0
# 35                     0.0000                      1960.0
# 40                     0.0000                      4452.0
# 44                     0.0000                     13961.0
# 45                     0.0000                     13058.0
# 47                     0.0000                      6081.0
#
#     sow_tot_revol_bal_amt  sow_tot_revol_cnt  sow_tot_trans_bal_amt  \
# 0                     0.0                0.0                    0.0
# 1                    24.0                2.0                    0.0
# 4                  2606.0                5.0                  143.0
# 6                   441.0                2.0                 1866.0
# 7                     0.0                0.0                 5833.0
# 11                    0.0                0.0                    0.0
# 12                 -546.0                2.0                    0.0
# 14                    0.0                0.0                  303.0
# 18                    0.0                0.0                    0.0
# 24                    0.0                0.0                    0.0
# 27                 1286.0                2.0                    0.0
# 29                    0.0                0.0                  893.0
# 30                    0.0                0.0                    0.0
# 31                    0.0                0.0                    0.0
# 32                    0.0                0.0                    0.0
# 35                    0.0                0.0                   57.0
# 40                    0.0                0.0                    0.0
# 44                    0.0                0.0                  877.0
# 45                    0.0                0.0                  560.0
# 47                    0.0                0.0                 2202.0
#
#     sow_tot_trans_cnt
# 0                 3.0
# 1                 0.0
# 4                13.0
# 6                 2.0
# 7                 6.0
# 11                3.0
# 12                0.0
# 14                4.0
# 18                0.0
# 24                0.0
# 27                0.0
# 29                3.0
# 30                0.0
# 31                0.0
# 32                0.0
# 35                2.0
# 40                2.0
# 44                2.0
# 45                2.0
# 47                3.0
#
# [20 rows x 50 columns]

# %%
##----------------------------------------------DATA CLEANING DONE------------------------------------------------##

# %%
from matplotlib import pyplot as plt

# %%
#Correlatiom between profitable flag and flag to indicate if customer has set up autopayment
data['profitable_flag'].corr(data['direct_debit_ind'])
# Out:
# 0.030862827153762

# %%
data['profitable_flag'].corr(data['cdss_most_rcnt_prob']) #Correlation between internal risk score and proftiable flag
# Out:
# -0.0321857739819944

# %%
plt.plot(data['cdss_most_rcnt_prob'], data['profitable_flag'], 'ro') #

# %%
##External Bureau score (Credit worthiness) and Credit Limit of all cards of customer (More credit worthy, more credit cards he's eligible for is the logic)

# %%
data['profitable_flag'].corr(data['cbr_3_score']) #Correlation between profitable flag and external bureau score of
#customer
# Out:
# 0.03012096997629511

# %%
#Credit bureau score = x-axis, profitable flag count = y-axis

figure = plt.figure(figsize=(25, 7))
plt.hist([data['cbr_3_score'][data['profitable_flag'] == 0], data['cbr_3_score'][data['profitable_flag'] == 1]], stacked= True, color = ['g', 'r'], bins =40, label = ['no', 'yes'])
plt.legend()

# %%
#profitable flag vs total credit limits of all cards of the customer
figure = plt.figure(figsize=(25, 7))
plt.hist([data[data['profitable_flag'] == 0]['sum_total_line_amt'], data[data['profitable_flag'] == 1]['sum_total_line_amt']], stacked=True, color = ['g', 'r'], bins = 30, label = ['no', 'yes'])
plt.legend()

# %%
#Plot of total limit on all credit cards vs external bureau score
figure = plt.figure(figsize=(25,7))
plt.plot(data['cbr_3_score'], data['sum_total_line_amt'], 'ro')

# %%
#profitable flag vs profit brought by customer in last 6 months
figure = plt.figure(figsize=(25, 7))
plt.hist([data['pre6m_total_mc_trs'][data['profitable_flag'] == 0], data['pre6m_total_mc_trs'][data['profitable_flag'] == 1]], stacked= True, color = ['g', 'r'], bins =40, label = ['no', 'yes'])
plt.legend()

# %%
print('Negative profit, Profitability flag = 0')
print(len(data[data['pre6m_total_mc_trs'] < 0][data['profitable_flag'] == 0].index))
print('\n')

print('Positive profit, Profitability flag = 0')
print(len(data[data['pre6m_total_mc_trs'] >= 0][data['profitable_flag'] == 0].index))
print('\n')

print('Negative profit, Profitability flag = 1')
print(len(data[data['pre6m_total_mc_trs'] < 0][data['profitable_flag'] == 1].index))
print('\n')

print('Positive profit, Profitability flag = 1')
print(len(data[data['pre6m_total_mc_trs'] >= 0][data['profitable_flag'] == 1].index))
print('\n')
# Out:
# Negative profit, Profitability flag = 0
# 6049
#
#
# Positive profit, Profitability flag = 0
# 8880
#
#
# Negative profit, Profitability flag = 1
# 1090
#
#
# Positive profit, Profitability flag = 1
# 2338
# <ipython-input-24-64fc22169249>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(len(data[data['pre6m_total_mc_trs'] < 0][data['profitable_flag'] == 0].index))
# <ipython-input-24-64fc22169249>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(len(data[data['pre6m_total_mc_trs'] >= 0][data['profitable_flag'] == 0].index))
# <ipython-input-24-64fc22169249>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(len(data[data['pre6m_total_mc_trs'] < 0][data['profitable_flag'] == 1].index))
# <ipython-input-24-64fc22169249>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(len(data[data['pre6m_total_mc_trs'] >= 0][data['profitable_flag'] == 1].index))

# %%
#CLQ = Flag is customer is low quality indicator 
print('CLQ = 0, Profitability flag = 0')
print(len(data[data['Customer Low Quality indicator'] == 0][data['profitable_flag'] == 0].index))
print('\n')

print('CLQ = 1, Profitability flag = 0')
print(len(data[data['Customer Low Quality indicator'] == 1][data['profitable_flag'] == 0].index))
print('\n')

print('CLQ = 0, Profitability flag = 1')
print(len(data[data['Customer Low Quality indicator'] == 0][data['profitable_flag'] == 1].index))
print('\n')

print('CLQ = 1, Profitability flag = 1')
print(len(data[data['Customer Low Quality indicator'] == 1][data['profitable_flag'] == 1].index))
print('\n')

print('Correlation:')
print(data['profitable_flag'].corr(data['Customer Low Quality indicator']))
# Out:
# CLQ = 0, Profitability flag = 0
# 14785
#
#
# CLQ = 1, Profitability flag = 0
# 144
#
#
# CLQ = 0, Profitability flag = 1
# 3416
#
#
# CLQ = 1, Profitability flag = 1
# 12
#
#
# Correlation:
# -0.02608872561139689
# <ipython-input-25-be24d355f703>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(len(data[data['Customer Low Quality indicator'] == 0][data['profitable_flag'] == 0].index))
# <ipython-input-25-be24d355f703>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(len(data[data['Customer Low Quality indicator'] == 1][data['profitable_flag'] == 0].index))
# <ipython-input-25-be24d355f703>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(len(data[data['Customer Low Quality indicator'] == 0][data['profitable_flag'] == 1].index))
# <ipython-input-25-be24d355f703>:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   print(len(data[data['Customer Low Quality indicator'] == 1][data['profitable_flag'] == 1].index))
